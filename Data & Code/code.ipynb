# %%
import pandas as pd

# %%
data = pd.read_csv("../Dados/musaranhoClean.csv")

data.columns
# Out:
# Index(['id', 'time_observed_at', 'user_id', 'user_login', 'created_at',
#        'place_town_name', 'place_county_name', 'place_state_name',
#        'place_country_name', 'place_admin1_name', 'place_admin2_name'],
#       dtype='object')

# %%
placesCount = data.groupby('place_county_name').size().reset_index(name='observations')


placesCount.plot.bar(x='place_county_name',y='observations')

# %%
data.groupby('user_login').size().reset_index(name='observations')
# Out:
#              user_login  observations
# 0                adriao             2
# 1         avesdabatalha             1
# 2                axeira             2
# 3      catarina_biologa             1
# 4               danimon             1
# 5       davideleoberton             1
# 6          davidrosario             1
# 7             draposo79             1
# 8                duarte             1
# 9          francisco100             2
# 10              hecosta             1
# 11       henriquemiguel             1
# 12          hugobarbosa             1
# 13             jdinares             2
# 14     joaotiagotavares             1
# 15             jpmalves             1
# 16         kikacoutinho             1
# 17             ldacosta             1
# 18            lgordinho             1
# 19          llourenco92             1
# 20        marioestevens             1
# 21                micss             1
# 22  miguel_rod_ferreira             1
# 23     miguelberkemeier             1
# ...
